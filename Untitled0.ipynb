# %%
# %cd /content/drive/MyDrive/PHD/neural topic model/cluster optimal transport/TopiCOT_MMI
# Out:
# /content/drive/MyDrive/PHD/neural topic model/cluster optimal transport/TopiCOT_MMI

# %%
# !unzip Wikipedia_bd.zip
# Out:
# Archive:  Wikipedia_bd.zip
#    creating: wikipedia_bd/
#   inflating: wikipedia_bd.histogram
#   inflating: wikipedia_bd/_3f5.cfe
#   inflating: wikipedia_bd/_3f5.cfs
#   inflating: wikipedia_bd/_3f5.si
#   inflating: wikipedia_bd/_3gj.fdt
#   inflating: wikipedia_bd/_3gj.fdx
#   inflating: wikipedia_bd/_3gj.fnm
#   inflating: wikipedia_bd/_3gj.nvd
#  extracting: wikipedia_bd/_3gj.nvm
#   inflating: wikipedia_bd/_3gj.si
#   inflating: wikipedia_bd/_3gj.tvd
#   inflating: wikipedia_bd/_3gj.tvx
#   inflating: wikipedia_bd/_3gj_Lucene41_0.doc
#   inflating: wikipedia_bd/_3gj_Lucene41_0.pos
#   inflating: wikipedia_bd/_3gj_Lucene41_0.tim
#   inflating: wikipedia_bd/_3gj_Lucene41_0.tip
#   inflating: wikipedia_bd/_3gt.cfe
#   inflating: wikipedia_bd/_3gt.cfs
#   inflating: wikipedia_bd/_3gt.si
#   inflating: wikipedia_bd/_3ir.cfe
#   inflating: wikipedia_bd/_3ir.cfs
#   inflating: wikipedia_bd/_3ir.si
#   inflating: wikipedia_bd/_3j1.cfe
#   inflating: wikipedia_bd/_3j1.cfs
# ...

# %%
# !wget https://hobbitdata.informatik.uni-leipzig.de/homes/mroeder/palmetto/Wikipedia_bd.zip --no-check-certificate
# Out:
# --2024-11-12 09:30:37--  https://hobbitdata.informatik.uni-leipzig.de/homes/mroeder/palmetto/Wikipedia_bd.zip
# Resolving hobbitdata.informatik.uni-leipzig.de (hobbitdata.informatik.uni-leipzig.de)... 139.18.4.2, 2001:638:902:2004::4:2
# Connecting to hobbitdata.informatik.uni-leipzig.de (hobbitdata.informatik.uni-leipzig.de)|139.18.4.2|:443... connected.
# WARNING: cannot verify hobbitdata.informatik.uni-leipzig.de's certificate, issued by ‘CN=GEANT eScience SSL CA 4,O=GEANT Vereniging,C=NL’:
#   Issued certificate has expired.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://files-redirect.dice-research.org/homes/mroeder/palmetto/Wikipedia_bd.zip [following]
# --2024-11-12 09:30:38--  https://files-redirect.dice-research.org/homes/mroeder/palmetto/Wikipedia_bd.zip
# Resolving files-redirect.dice-research.org (files-redirect.dice-research.org)... 131.234.26.214
# ...

# %%
# !pip install torch-kmeans

# %%
# !python main.py --model TopiCOT --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 200.0 --alpha_ECR 20.0 --weight_DCR 40.0 --weight_TCR 150.0 --weight_loss_InfoNCE 0 --seed 0
# Out:
# 2024-11-12 18:27:10.161130: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-12 18:27:10.180508: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-12 18:27:10.186407: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-12 18:27:10.200587: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python main.py --model TopiCOT --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 200.0 --alpha_ECR 20.0 --weight_DCR 50.0 --weight_TCR 150.0 --weight_loss_InfoNCE 0 --seed 0
# Out:
# 2024-11-12 18:51:40.431952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-12 18:51:40.452822: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-12 18:51:40.459037: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-12 18:51:40.474160: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python main.py --model TopiCOT --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 200.0 --alpha_ECR 20.0 --weight_DCR 40.0 --weight_TCR 200.0 --weight_loss_InfoNCE 0 --seed 0
# Out:
# 2024-11-12 19:14:13.565151: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-12 19:14:13.584799: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-12 19:14:13.590741: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-12 19:14:13.604842: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python main.py --model TopiCOT --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 200.0 --alpha_ECR 20.0 --weight_DCR 50.0 --weight_TCR 200.0 --weight_loss_InfoNCE 0 --seed 0
# Out:
# 2024-11-12 19:36:45.955901: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-12 19:36:45.975774: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-12 19:36:45.981763: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-12 19:36:45.996452: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/PHD/neural topic model/cluster optimal transport/TopiCOT_MMI/.git/

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) 7a8f956] first commit
#  146 files changed, 226448 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 README.md
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 data/20NG/test_bow.npz
#  create mode 100644 data/20NG/test_labels.txt
#  create mode 100644 data/20NG/test_texts.txt
#  create mode 100644 data/20NG/train_bow.npz
#  create mode 100644 data/20NG/train_labels.txt
#  create mode 100644 data/20NG/train_texts.txt
#  create mode 100644 data/20NG/vocab.txt
#  create mode 100644 data/20NG/with_bert/test_bert.npz
#  create mode 100644 data/20NG/with_bert/train_bert.npz
#  create mode 100644 data/20NG/word_embeddings.npz
#  create mode 100644 data/AGNews/test_bow.npz
#  create mode 100644 data/AGNews/test_labels.txt
#  create mode 100644 data/AGNews/test_texts.txt
#  create mode 100644 data/AGNews/train_bow.npz
#  create mode 100644 data/AGNews/train_labels.txt
#  create mode 100644 data/AGNews/train_texts.txt
# ...

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/tungserver99/TopiCOT.git

# %%
# !git remote remove origin

# %%
# !git push -u origin main
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/tungserver99/TopiCOT.git/'
